# %%
import numpy as np
a=np.random.random((10,1))
print(np.mean(a))
# Out:
# 0.41812949699927976

# %%
a=np.random.rand(20,1)
b=np.std(a)
print("std deviation is ",b)
b=b**2
print('variance is',b)
# Out:
# std deviation is  0.28496206100460636
# variance is 0.081203376211993

# %%
a=np.random.rand(10,20)
b=np.random.rand(20,25)
g=np.matmul(a,b)
print(g)
print(np.sum(g))
# Out:
# [[4.16446124 4.45280221 5.24200502 3.88824282 4.30333464 5.90206583
#   4.17009115 4.4404389  4.46562091 6.05898665 4.02983848 5.29835067
#   3.85140477 5.02973405 4.95708134 4.97539163 5.67102138 3.32975216
#   4.58989735 5.25543823 3.9174222  4.60711111 6.41799498 4.2326418
#   4.56445246]
#  [4.19009461 4.14255372 4.20789488 3.27199502 4.37220663 5.08761403
#   3.75031982 3.36569758 4.39703258 4.93805654 3.11696985 4.10453047
#   3.86136766 4.68526176 4.789703   3.70226457 3.63834043 2.63962596
#   3.18305914 4.7414617  3.53210346 4.0250211  5.29267241 3.76055649
#   4.78611582]
#  [4.59108564 4.56308159 4.39663316 3.45297749 3.69014801 4.69214764
#   3.97662923 4.74207152 4.04099603 4.68427093 3.25839309 4.36801225
#   3.46307599 4.48486207 4.32640387 4.53502186 4.84141147 3.5654364
#   4.14131009 4.41615848 3.62466305 5.10323739 5.48306813 4.45215791
#   4.71739699]
#  [4.48595769 5.37983226 5.19484692 3.77313511 3.84789074 5.7937246
# ...

# %%
a=np.random.rand(10,1)
print(a)
def func(x):
    return 1/(1+np.exp(-x))
b=func(a)
print(b)
# Out:
# [[0.98464567]
#  [0.52871985]
#  [0.98597896]
#  [0.79270297]
#  [0.12635445]
#  [0.85871945]
#  [0.43270704]
#  [0.94924089]
#  [0.21785066]
#  [0.86155757]]
# [[0.72802905]
#  [0.62918449]
#  [0.72829296]
#  [0.68841142]
#  [0.53154665]
#  [0.70239304]
#  [0.6065199 ]
#  [0.72096249]
#  [0.55424829]
#  [0.70298597]]
